# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Lambda, Layer, Conv2D, Conv2DTranspose, Flatten, Reshape, MaxPooling2D
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.losses import mean_squared_error, binary_crossentropy, kullback_leibler_divergence
from tensorflow.keras.callbacks import EarlyStopping, TerminateOnNaN, ReduceLROnPlateau
from tensorflow.keras import backend as K
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc, roc_auc_score

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os, scipy
from sklearn.model_selection import train_test_split

from phenom_read_in_data import *
from fpr_tpr_calc import *

# %%
path1 = '/home/joe/Documents/Work/PhD/dark_machines/training_files/chan3/signals/glgl1400_neutralino1100_chan3.csv'
path2 = '/home/joe/Documents/Work/PhD/dark_machines/training_files/chan3/signals/glgl1600_neutralino800_chan3.csv'
path3 = '/home/joe/Documents/Work/PhD/dark_machines/training_files/chan3/signals/gluino_1000.0_neutralino_1.0_chan3_200000.csv'
path4 = '/home/joe/Documents/Work/PhD/dark_machines/training_files/chan3/signals/monoV_Zp2000.0_DM_1.0_chan3.csv'
path5 = '/home/joe/Documents/Work/PhD/dark_machines/training_files/chan3/signals/monojet_Zp2000.0_DM_50.0_chan3.csv'
path6 = '/home/joe/Documents/Work/PhD/dark_machines/training_files/chan3/signals/monotop_200_A_chan3.csv'
path7 = '/home/joe/Documents/Work/PhD/dark_machines/training_files/chan3/signals/sqsq1_sq1400_neut800_chan3.csv'
path8 = '/home/joe/Documents/Work/PhD/dark_machines/training_files/chan3/signals/sqsq_sq1800_neut800_chan3.csv'
path9 = '/home/joe/Documents/Work/PhD/dark_machines/training_files/chan3/signals/stlp_st1000_chan3.csv'
path10 = '/home/joe/Documents/Work/PhD/dark_machines/training_files/chan3/signals/stop2b1000_neutralino300_chan3.csv'

# %%
paths = [path1, path2, path3, path4, path5, path6, path7, path8, path9, path10]

# %%
#Getthe data
df_bkg = single_csv_to_df('/home/joe/Documents/Work/PhD/dark_machines/training_files/chan3/background_chan3_8.02_200000.csv')

# %%
for path in paths:
    temp = single_csv_to_df(path)
    if (len(temp.columns) > len(df_bkg.columns)):
        diff = int(((len(temp.columns)-5)/5))-int(((len(df_bkg.columns)-5)/5))
        num = int(((len(df_bkg.columns) - 5)/5) + 1)
        for i in range(diff):
            df_bkg['obj'+str(num)]= -999
            df_bkg['E'+str(num)] = -999
            df_bkg['pt'+str(num)] = -999
            df_bkg['eta'+str(num)] = -999
            df_bkg['phi'+str(num)] = -999
            num+=1

# %%
df_bkg
# Out:
#          event_ID process_ID event_weight     MET     MET_Phi obj1      E1  \
# 0        16941885      njets            1  100881     2.25584    j  905538
# 1       159940776      njets            1  144050   -0.412954    b  470651
# 2       168908747      njets            1  104442    0.180383    j  288901
# 3       144004174      njets            1  193479  -0.0460751    j  881925
# 4        55406310      njets            1  139352     -1.5856    j  619966
# ...           ...        ...          ...     ...         ...  ...     ...
# 199995  164475365      njets            1  143422    -0.30802    j  809590
# 199996   77476112      njets            1  103228    0.997506    j  501438
# 199997   56243201      njets            1  110893     1.70124    j  358506
# 199998    2149006      njets            1  156856     2.50748    j  371246
# 199999    4457235      njets            1  118182     2.43961    j  645121
#
#            pt1        eta1       phi1  ... obj18  E18 pt18 eta18 phi18 obj19  \
# 0       466807    -1.28025   -0.97045  ...  -999 -999 -999  -999  -999  -999
# 1       358331   -0.770564   -0.35984  ...  -999 -999 -999  -999  -999  -999
# 2       268383    0.354942   0.304771  ...  -999 -999 -999  -999  -999  -999
# 3       471724    -1.23801    3.08542  ...  -999 -999 -999  -999  -999  -999
# 4       406938   -0.981054    1.61988  ...  -999 -999 -999  -999  -999  -999
# ...        ...         ...        ...  ...   ...  ...  ...   ...   ...   ...
# 199995  409811     1.30099   -3.00886  ...  -999 -999 -999  -999  -999  -999
# 199996  402542   -0.681099   -2.02738  ...  -999 -999 -999  -999  -999  -999
# 199997  317238   -0.493772    1.40277  ...  -999 -999 -999  -999  -999  -999
# 199998  370114  -0.0171899    2.67509  ...  -999 -999 -999  -999  -999  -999
# 199999  618178   -0.287432  -0.808173  ...  -999 -999 -999  -999  -999  -999
#
#         E19 pt19 eta19 phi19
# 0      -999 -999  -999  -999
# 1      -999 -999  -999  -999
# 2      -999 -999  -999  -999
# 3      -999 -999  -999  -999
# 4      -999 -999  -999  -999
# ...     ...  ...   ...   ...
# 199995 -999 -999  -999  -999
# 199996 -999 -999  -999  -999
# 199997 -999 -999  -999  -999
# 199998 -999 -999  -999  -999
# 199999 -999 -999  -999  -999
#
# [200000 rows x 100 columns]

# %%
#If the number of max objects is prime, another column needs to be added to mitigate

# %%
if ((len(df_bkg.columns)-5) % 2 != 0):
    num = str(int(((len(df_bkg.columns) - 5)/5) + 1))
    df_bkg['obj'+num]= -999
    df_bkg['E'+num] = -999
    df_bkg['pt'+num] = -999
    df_bkg['eta'+num] = -999
    df_bkg['phi'+num] = -999

# %%
df_bkg
# Out:
#          event_ID process_ID event_weight     MET     MET_Phi obj1      E1  \
# 0        16941885      njets            1  100881     2.25584    j  905538
# 1       159940776      njets            1  144050   -0.412954    b  470651
# 2       168908747      njets            1  104442    0.180383    j  288901
# 3       144004174      njets            1  193479  -0.0460751    j  881925
# 4        55406310      njets            1  139352     -1.5856    j  619966
# ...           ...        ...          ...     ...         ...  ...     ...
# 199995  164475365      njets            1  143422    -0.30802    j  809590
# 199996   77476112      njets            1  103228    0.997506    j  501438
# 199997   56243201      njets            1  110893     1.70124    j  358506
# 199998    2149006      njets            1  156856     2.50748    j  371246
# 199999    4457235      njets            1  118182     2.43961    j  645121
#
#            pt1        eta1       phi1  ... obj19  E19 pt19 eta19 phi19 obj20  \
# 0       466807    -1.28025   -0.97045  ...  -999 -999 -999  -999  -999  -999
# 1       358331   -0.770564   -0.35984  ...  -999 -999 -999  -999  -999  -999
# 2       268383    0.354942   0.304771  ...  -999 -999 -999  -999  -999  -999
# 3       471724    -1.23801    3.08542  ...  -999 -999 -999  -999  -999  -999
# 4       406938   -0.981054    1.61988  ...  -999 -999 -999  -999  -999  -999
# ...        ...         ...        ...  ...   ...  ...  ...   ...   ...   ...
# 199995  409811     1.30099   -3.00886  ...  -999 -999 -999  -999  -999  -999
# 199996  402542   -0.681099   -2.02738  ...  -999 -999 -999  -999  -999  -999
# 199997  317238   -0.493772    1.40277  ...  -999 -999 -999  -999  -999  -999
# 199998  370114  -0.0171899    2.67509  ...  -999 -999 -999  -999  -999  -999
# 199999  618178   -0.287432  -0.808173  ...  -999 -999 -999  -999  -999  -999
#
#         E20 pt20 eta20 phi20
# 0      -999 -999  -999  -999
# 1      -999 -999  -999  -999
# 2      -999 -999  -999  -999
# 3      -999 -999  -999  -999
# 4      -999 -999  -999  -999
# ...     ...  ...   ...   ...
# 199995 -999 -999  -999  -999
# 199996 -999 -999  -999  -999
# 199997 -999 -999  -999  -999
# 199998 -999 -999  -999  -999
# 199999 -999 -999  -999  -999
#
# [200000 rows x 105 columns]

# %%
df = df_bkg.fillna(-999)
variables = [entry for entry in df.columns if entry[0] == 'E'] + [entry for entry in df.columns if entry[0:2] == 'pt'] + [entry for entry in df.columns if entry[0:2] == 'et'] + [entry for entry in df.columns if entry[0:2] == 'ph']

# %%
#Now we one_hot encode the data to make sure we have a class definition
df = df[['process_ID']+variables]
one_hot = pd.get_dummies(df['process_ID'])
processes = one_hot.columns
df.drop('process_ID', axis = 'columns', inplace = True)
df = pd.concat([df, one_hot], sort = False, axis = 1)

# %%
E = [entry for entry in df.columns if entry[0] == 'E']
pt = [entry for entry in df.columns if entry[0:2] == 'pt']
eta = [entry for entry in df.columns if entry[0:2] == 'et']
phi = [entry for entry in df.columns if entry[0:2] == 'ph']

# %%
np_E = np.array(df[E])
np_pt = np.array(df[pt])
np_eta = np.array(df[eta])
np_phi = np.array(df[phi])

# %%
#We have created a df of our values and some kind of class label
#We should normalize
x = df[variables].values
x_scaled = StandardScaler().fit_transform(x)
df[variables] = x_scaled

x_train, x_test, y_train, y_test = train_test_split(df[variables].values,
                                                    df[processes].values, 
                                                    shuffle = True,
                                                    random_state = 42,
                                                    test_size = 0.1)

# %%
#Reshape the data. This will have to be done explicitly until you think of a clever way of doing it
x_train = x_train.reshape((x_train.shape[0], 1, -1, 4))
x_test = x_test.reshape((x_test.shape[0], 1, -1, 4))

# %%
#VAE Model
original_dim = x_train.shape[0]
input_shape = x_train.shape[1:]
latent_dim = 4
intermediate_dim = 50
kernel_max_norm = 1000.
act_fun = 'relu'
epsilon_std = 1.
filters = 32
kernel_size = (2, 2)
strides = (1, 1)
pool_size = (1, 1)

# %%
K.clear_session()

# %%
def sampling(args):
    z_mean, z_log_var=args
    epsilon=tf.random.uniform(shape=(K.shape(z_mean)[0], latent_dim))
    return z_mean+K.exp(z_log_var/2)*epsilon
    
#Define some losses
def kl_loss(y_true, y_pred):
    kl_loss = 1 + z_var - K.square(z_mean) - K.exp(z_var)
    kl_loss = K.sum(kl_loss, axis=-1)
    kl_loss *= -0.5
    #kl_loss = K.mean(kl_loss)
    return kl_loss

def recon_loss(y_true, y_pred):
    recon_loss = mean_squared_error(K.flatten(y_true), K.flatten(y_pred))
    recon_loss *= shape[0]*shape[1]*shape[2]
    #recon_loss = K.mean(recon_loss)
    return recon_loss
    
def my_vae_loss(y_true, y_pred):
    beta = 0.1
    recon = recon_loss(y_true, y_pred) 
    kl = kl_loss(y_true, y_pred)
    vae_loss = (1-beta)*recon + beta*kl
    return vae_loss

    
    #Layers
x_input = Input(shape = input_shape, name = 'Input')
conv_1 = Conv2D(filters = filters, 
                activation = act_fun,
                kernel_size = kernel_size,
                strides = strides, 
                padding = 'same', 
                name = 'conv_1')(x_input)
pool_1 = MaxPooling2D(pool_size = pool_size,
                          strides = 2, 
                          name = 'max_pool')(conv_1)
conv_2 = Conv2D(filters = filters, 
                activation = act_fun, 
                kernel_size = kernel_size, 
                strides = strides, 
                padding = 'same', 
                name = 'conv_2')(pool_1)
#Shape info needed to inform the dense layer in the decoder
flatten = Flatten()(conv_2)#(pool_1)
cnn = Model(x_input, flatten, name = 'cnn')
cnn.summary()

shape = input_shape
    
#Encoding
dense_encoder_1 = Dense(intermediate_dim,
                            activation = act_fun,
                            name = 'dense_encoder_1')(flatten)
dense_encoder_2 = Dense(16,
                            activation = act_fun,
                            name = 'dense_encoder_2')(dense_encoder_1)
z_mean = Dense(latent_dim, name = 'z_mean')(dense_encoder_2)
z_var = Dense(latent_dim, name = 'z_var')(dense_encoder_2)

z = Lambda(sampling, output_shape = (latent_dim, ), name = 'sampling')([z_mean, z_var])

encoder = Model(x_input, [z_mean, z_var, z], name = 'encoder')
encoder.summary()
    
#Decoding
dense_shape = shape[0]*shape[1]*shape[2]
decoder_input = Input(shape = (latent_dim, ), name = 'decoder_input')
dense_decoder_1 = Dense(dense_shape, 
                            activation = act_fun, 
                            name = 'dense_decoder_1')(decoder_input)
reshape = Reshape((shape[0], shape[1], shape[2]))(dense_decoder_1)

deconv_1 = Conv2DTranspose(filters = filters,
                               kernel_size = kernel_size, 
                               activation = act_fun, 
                               strides = strides, 
                               padding = 'same', 
                               name = 'deconv_1')(reshape)
deconv_2 = Conv2DTranspose(filters = 20,
                               kernel_size = kernel_size, 
                               activation = act_fun, 
                               strides = strides, 
                               padding = 'same', 
                               name = 'deconv_2')(deconv_1)

output = Conv2DTranspose(filters = 4, 
                             kernel_size = kernel_size, 
                             #activation = 'sigmoid', 
                             padding = 'same', 
                             strides = strides, 
                             name = 'decoder_output')(deconv_2)

decoder = Model(decoder_input, output, name = 'decoder')
decoder.summary()
    
#Build the VAE model
#outputs = decoder(encoder(x_input)[2])
#vae = Model(x_input, outputs, name = 'vae')
    
#vae.compile(optimizer = 'rmsprop', loss = my_vae_loss, metrics = [kl_loss, recon_loss])
#vae.summary()
# Out:
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 1, 20, 4)]        0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 1, 20, 32)         544
# _________________________________________________________________
# max_pool (MaxPooling2D)      (None, 1, 10, 32)         0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 1, 10, 32)         4128
# _________________________________________________________________
# flatten (Flatten)            (None, 320)               0
# =================================================================
# Total params: 4,672
# Trainable params: 4,672
# Non-trainable params: 0
# _________________________________________________________________
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 1, 20, 4)]   0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 1, 20, 32)    544         Input[0][0]
# __________________________________________________________________________________________________
# max_pool (MaxPooling2D)         (None, 1, 10, 32)    0           conv_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 1, 10, 32)    4128        max_pool[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 320)          0           conv_2[0][0]
# __________________________________________________________________________________________________
# dense_encoder_1 (Dense)         (None, 50)           16050       flatten[0][0]
# __________________________________________________________________________________________________
# dense_encoder_2 (Dense)         (None, 16)           816         dense_encoder_1[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 4)            68          dense_encoder_2[0][0]
# __________________________________________________________________________________________________
# z_var (Dense)                   (None, 4)            68          dense_encoder_2[0][0]
# __________________________________________________________________________________________________
# sampling (Lambda)               (None, 4)            0           z_mean[0][0]
#                                                                  z_var[0][0]
# ==================================================================================================
# Total params: 21,674
# Trainable params: 21,674
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 4)]               0
# _________________________________________________________________
# dense_decoder_1 (Dense)      (None, 80)                400
# _________________________________________________________________
# reshape (Reshape)            (None, 1, 20, 4)          0
# _________________________________________________________________
# deconv_1 (Conv2DTranspose)   (None, 1, 20, 32)         544
# _________________________________________________________________
# deconv_2 (Conv2DTranspose)   (None, 1, 20, 20)         2580
# _________________________________________________________________
# decoder_output (Conv2DTransp (None, 1, 20, 4)          324
# =================================================================
# Total params: 3,848
# Trainable params: 3,848
# Non-trainable params: 0
# _________________________________________________________________

# %%
class Sampling(Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape =(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

class bVAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(bVAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        
    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]

        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = encoder(data)
            reconstruction = decoder(z)
            reconstruction_loss = tf.reduce_mean(
                keras.losses.mse(data, reconstruction)
            )
            reconstruction_loss *= 14*4
            kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
            kl_loss = tf.reduce_mean(kl_loss)
            kl_loss *= -0.5
            beta = 0.1
            total_loss = (1-beta)*reconstruction_loss + beta*kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            "kl_loss": kl_loss,
        }
    
    #def call(self, inputs, **kwargs):
    #    return self.model(inputs, decoder)

# %%
#Build the VAE model
#outputs = decoder(encoder(x_input)[2])
bvae = bVAE(encoder, decoder)
bvae.compile(optimizer = 'rmsprop')#, loss = my_vae_loss, metrics = [kl_loss, recon_loss])

# %%
x_val = x_train[:int(len(x_train)/3.)]
x_train = x_train[int(len(x_train)/3.):]

# %%
epochs = 100
batch_size = 1000
history_val = bvae.fit(x = x_val, epochs = epochs, batch_size = batch_size, verbose = 0)

history_train = bvae.fit(x = x_train, epochs = epochs, batch_size = batch_size, verbose = 2)
# Out:
# Epoch 1/100
# 120/120 - 6s - loss: 4.1988 - reconstruction_loss: 4.4015 - kl_loss: 2.3753
# Epoch 2/100
# 120/120 - 6s - loss: 3.7834 - reconstruction_loss: 3.9430 - kl_loss: 2.3477
# Epoch 3/100
# 120/120 - 6s - loss: 3.8765 - reconstruction_loss: 4.0463 - kl_loss: 2.3483
# Epoch 4/100
# 120/120 - 6s - loss: 4.1165 - reconstruction_loss: 4.2941 - kl_loss: 2.5187
# Epoch 5/100
# 120/120 - 6s - loss: 6.6676 - reconstruction_loss: 6.7712 - kl_loss: 5.7354
# Epoch 6/100
# 120/120 - 6s - loss: 3.7795 - reconstruction_loss: 3.9456 - kl_loss: 2.2851
# Epoch 7/100
# 120/120 - 6s - loss: 3.9910 - reconstruction_loss: 4.1741 - kl_loss: 2.3426
# Epoch 8/100
# 120/120 - 6s - loss: 4.9955 - reconstruction_loss: 5.1361 - kl_loss: 3.7294
# Epoch 9/100
# 120/120 - 6s - loss: 5.0906 - reconstruction_loss: 5.1928 - kl_loss: 4.1711
# Epoch 10/100
# 120/120 - 6s - loss: 3.7174 - reconstruction_loss: 3.8979 - kl_loss: 2.0931
# Epoch 11/100
# 120/120 - 6s - loss: 4.1830 - reconstruction_loss: 4.3555 - kl_loss: 2.6301
# Epoch 12/100
# 120/120 - 6s - loss: 4.0493 - reconstruction_loss: 4.2452 - kl_loss: 2.2862
# Epoch 13/100
# 120/120 - 6s - loss: 3.3239 - reconstruction_loss: 3.4598 - kl_loss: 2.1004
# Epoch 14/100
# 120/120 - 6s - loss: 3.7066 - reconstruction_loss: 3.8656 - kl_loss: 2.2761
# Epoch 15/100
# 120/120 - 6s - loss: 12.8834 - reconstruction_loss: 11.4310 - kl_loss: 25.9547
# Epoch 16/100
# 120/120 - 6s - loss: 3.6662 - reconstruction_loss: 3.8414 - kl_loss: 2.0893
# Epoch 17/100
# 120/120 - 6s - loss: 3.7787 - reconstruction_loss: 3.9581 - kl_loss: 2.1637
# Epoch 18/100
# 120/120 - 6s - loss: 4.1115 - reconstruction_loss: 4.2721 - kl_loss: 2.6654
# Epoch 19/100
# 120/120 - 6s - loss: 3.7745 - reconstruction_loss: 3.9342 - kl_loss: 2.3374
# Epoch 20/100
# 120/120 - 6s - loss: 4.0511 - reconstruction_loss: 4.2710 - kl_loss: 2.0720
# Epoch 21/100
# 120/120 - 6s - loss: 4.0952 - reconstruction_loss: 4.2516 - kl_loss: 2.6876
# Epoch 22/100
# 120/120 - 6s - loss: 3.6102 - reconstruction_loss: 3.7695 - kl_loss: 2.1772
# Epoch 23/100
# 120/120 - 6s - loss: 3.5780 - reconstruction_loss: 3.7331 - kl_loss: 2.1819
# Epoch 24/100
# 120/120 - 6s - loss: 4.5327 - reconstruction_loss: 4.6097 - kl_loss: 3.8394
# Epoch 25/100
# 120/120 - 6s - loss: 3.6555 - reconstruction_loss: 3.7851 - kl_loss: 2.4889
# Epoch 26/100
# 120/120 - 6s - loss: 3.5571 - reconstruction_loss: 3.7197 - kl_loss: 2.0942
# Epoch 27/100
# 120/120 - 6s - loss: 4.1943 - reconstruction_loss: 4.3258 - kl_loss: 3.0116
# Epoch 28/100
# 120/120 - 6s - loss: 4.1551 - reconstruction_loss: 4.3146 - kl_loss: 2.7199
# Epoch 29/100
# 120/120 - 6s - loss: 3.8350 - reconstruction_loss: 4.0155 - kl_loss: 2.2102
# Epoch 30/100
# 120/120 - 6s - loss: 4.2070 - reconstruction_loss: 4.3938 - kl_loss: 2.5257
# Epoch 31/100
# 120/120 - 6s - loss: 5.4500 - reconstruction_loss: 5.7389 - kl_loss: 2.8500
# Epoch 32/100
# 120/120 - 6s - loss: 3.6077 - reconstruction_loss: 3.7571 - kl_loss: 2.2627
# Epoch 33/100
# 120/120 - 6s - loss: 5.4404 - reconstruction_loss: 5.5140 - kl_loss: 4.7782
# Epoch 34/100
# 120/120 - 6s - loss: 4.9712 - reconstruction_loss: 4.9991 - kl_loss: 4.7196
# Epoch 35/100
# 120/120 - 6s - loss: 5.0695 - reconstruction_loss: 5.2823 - kl_loss: 3.1539
# Epoch 36/100
# 120/120 - 6s - loss: 3.6646 - reconstruction_loss: 3.8226 - kl_loss: 2.2425
# Epoch 37/100
# 120/120 - 6s - loss: 16.6919 - reconstruction_loss: 15.9239 - kl_loss: 23.6041
# Epoch 38/100
# 120/120 - 6s - loss: 3.4877 - reconstruction_loss: 3.6204 - kl_loss: 2.2930
# Epoch 39/100
# 120/120 - 6s - loss: 5.7379 - reconstruction_loss: 6.0536 - kl_loss: 2.8968
# Epoch 40/100
# 120/120 - 6s - loss: 3.4025 - reconstruction_loss: 3.5396 - kl_loss: 2.1691
# Epoch 41/100
# 120/120 - 6s - loss: 3.3863 - reconstruction_loss: 3.5103 - kl_loss: 2.2704
# Epoch 42/100
# 120/120 - 6s - loss: 3.5416 - reconstruction_loss: 3.6775 - kl_loss: 2.3188
# Epoch 43/100
# 120/120 - 6s - loss: 3.5096 - reconstruction_loss: 3.6576 - kl_loss: 2.1777
# Epoch 44/100
# 120/120 - 6s - loss: 4.1450 - reconstruction_loss: 4.3127 - kl_loss: 2.6362
# Epoch 45/100
# 120/120 - 6s - loss: 3.8233 - reconstruction_loss: 3.9819 - kl_loss: 2.3961
# Epoch 46/100
# 120/120 - 6s - loss: 3.5398 - reconstruction_loss: 3.6782 - kl_loss: 2.2946
# Epoch 47/100
# 120/120 - 6s - loss: 4.0997 - reconstruction_loss: 4.2758 - kl_loss: 2.5151
# Epoch 48/100
# 120/120 - 6s - loss: 4.7192 - reconstruction_loss: 4.9574 - kl_loss: 2.5751
# Epoch 49/100
# 120/120 - 6s - loss: 3.6763 - reconstruction_loss: 3.8249 - kl_loss: 2.3385
# Epoch 50/100
# 120/120 - 6s - loss: 3.8104 - reconstruction_loss: 3.9762 - kl_loss: 2.3181
# Epoch 51/100
# 120/120 - 6s - loss: 3.1646 - reconstruction_loss: 3.2739 - kl_loss: 2.1811
# Epoch 52/100
# 120/120 - 6s - loss: 4.3504 - reconstruction_loss: 4.5764 - kl_loss: 2.3167
# Epoch 53/100
# 120/120 - 6s - loss: 3.5559 - reconstruction_loss: 3.7007 - kl_loss: 2.2526
# Epoch 54/100
# 120/120 - 6s - loss: 3.5748 - reconstruction_loss: 3.7248 - kl_loss: 2.2253
# Epoch 55/100
# 120/120 - 6s - loss: 3.7537 - reconstruction_loss: 3.9179 - kl_loss: 2.2756
# Epoch 56/100
# 120/120 - 6s - loss: 4.3922 - reconstruction_loss: 4.4875 - kl_loss: 3.5346
# Epoch 57/100
# 120/120 - 6s - loss: 3.3732 - reconstruction_loss: 3.5112 - kl_loss: 2.1312
# Epoch 58/100
# 120/120 - 6s - loss: 3.7314 - reconstruction_loss: 3.8829 - kl_loss: 2.3681
# Epoch 59/100
# 120/120 - 6s - loss: 3.3151 - reconstruction_loss: 3.4190 - kl_loss: 2.3807
# Epoch 60/100
# 120/120 - 6s - loss: 3.4391 - reconstruction_loss: 3.5439 - kl_loss: 2.4952
# Epoch 61/100
# 120/120 - 6s - loss: 4.2435 - reconstruction_loss: 4.4482 - kl_loss: 2.4014
# Epoch 62/100
# 120/120 - 6s - loss: 4.9596 - reconstruction_loss: 4.9860 - kl_loss: 4.7225
# Epoch 63/100
# 120/120 - 6s - loss: 4.2083 - reconstruction_loss: 4.3454 - kl_loss: 2.9742
# Epoch 64/100
# 120/120 - 6s - loss: 16.9569 - reconstruction_loss: 17.1421 - kl_loss: 15.2898
# Epoch 65/100
# 120/120 - 6s - loss: 3.5103 - reconstruction_loss: 3.6453 - kl_loss: 2.2954
# Epoch 66/100
# 120/120 - 6s - loss: 3.7091 - reconstruction_loss: 3.8659 - kl_loss: 2.2982
# Epoch 67/100
# 120/120 - 6s - loss: 3.4062 - reconstruction_loss: 3.5566 - kl_loss: 2.0526
# Epoch 68/100
# 120/120 - 6s - loss: 3.3169 - reconstruction_loss: 3.4320 - kl_loss: 2.2811
# Epoch 69/100
# 120/120 - 6s - loss: 5.1623 - reconstruction_loss: 5.2592 - kl_loss: 4.2901
# Epoch 70/100
# 120/120 - 6s - loss: 3.5766 - reconstruction_loss: 3.7118 - kl_loss: 2.3590
# Epoch 71/100
# 120/120 - 6s - loss: 3.6938 - reconstruction_loss: 3.8405 - kl_loss: 2.3735
# Epoch 72/100
# 120/120 - 6s - loss: 4.0306 - reconstruction_loss: 4.0156 - kl_loss: 4.1657
# Epoch 73/100
# 120/120 - 6s - loss: 3.3012 - reconstruction_loss: 3.3989 - kl_loss: 2.4217
# Epoch 74/100
# 120/120 - 5s - loss: 3.8694 - reconstruction_loss: 4.0153 - kl_loss: 2.5569
# Epoch 75/100
# 120/120 - 3s - loss: 3.5727 - reconstruction_loss: 3.7146 - kl_loss: 2.2947
# Epoch 76/100
# 120/120 - 3s - loss: 3.5702 - reconstruction_loss: 3.7085 - kl_loss: 2.3252
# Epoch 77/100
# 120/120 - 3s - loss: 3.6516 - reconstruction_loss: 3.7744 - kl_loss: 2.5470
# Epoch 78/100
# 120/120 - 3s - loss: 4.0898 - reconstruction_loss: 4.1745 - kl_loss: 3.3273
# Epoch 79/100
# 120/120 - 3s - loss: 3.5177 - reconstruction_loss: 3.6422 - kl_loss: 2.3970
# Epoch 80/100
# 120/120 - 3s - loss: 4.4707 - reconstruction_loss: 4.5843 - kl_loss: 3.4482
# Epoch 81/100
# 120/120 - 3s - loss: 3.2704 - reconstruction_loss: 3.3967 - kl_loss: 2.1339
# Epoch 82/100
# 120/120 - 3s - loss: 3.4481 - reconstruction_loss: 3.5502 - kl_loss: 2.5292
# Epoch 83/100
# 120/120 - 3s - loss: 3.3879 - reconstruction_loss: 3.4935 - kl_loss: 2.4379
# Epoch 84/100
# 120/120 - 3s - loss: 3.0555 - reconstruction_loss: 3.1656 - kl_loss: 2.0638
# Epoch 85/100
# 120/120 - 3s - loss: 3.5024 - reconstruction_loss: 3.6400 - kl_loss: 2.2642
# Epoch 86/100
# 120/120 - 3s - loss: 3.3451 - reconstruction_loss: 3.4648 - kl_loss: 2.2681
# Epoch 87/100
# 120/120 - 3s - loss: 3.4726 - reconstruction_loss: 3.6004 - kl_loss: 2.3217
# Epoch 88/100
# 120/120 - 3s - loss: 3.3858 - reconstruction_loss: 3.5056 - kl_loss: 2.3077
# Epoch 89/100
# 120/120 - 3s - loss: 3.3632 - reconstruction_loss: 3.4699 - kl_loss: 2.4026
# Epoch 90/100
# 120/120 - 3s - loss: 3.5629 - reconstruction_loss: 3.7084 - kl_loss: 2.2530
# Epoch 91/100
# 120/120 - 3s - loss: 3.2543 - reconstruction_loss: 3.3729 - kl_loss: 2.1874
# Epoch 92/100
# 120/120 - 3s - loss: 4.4490 - reconstruction_loss: 4.5693 - kl_loss: 3.3666
# Epoch 93/100
# 120/120 - 3s - loss: 3.5998 - reconstruction_loss: 3.7351 - kl_loss: 2.3826
# Epoch 94/100
# 120/120 - 4s - loss: 3.3577 - reconstruction_loss: 3.4594 - kl_loss: 2.4429
# Epoch 95/100
# 120/120 - 4s - loss: 3.7095 - reconstruction_loss: 3.8261 - kl_loss: 2.6605
# Epoch 96/100
# 120/120 - 4s - loss: 3.5668 - reconstruction_loss: 3.6888 - kl_loss: 2.4690
# Epoch 97/100
# 120/120 - 4s - loss: 3.4249 - reconstruction_loss: 3.5294 - kl_loss: 2.4849
# Epoch 98/100
# 120/120 - 4s - loss: 3.2677 - reconstruction_loss: 3.3722 - kl_loss: 2.3276
# Epoch 99/100
# 120/120 - 4s - loss: 3.4831 - reconstruction_loss: 3.5984 - kl_loss: 2.4456
# Epoch 100/100
# 120/120 - 4s - loss: 3.2591 - reconstruction_loss: 3.3612 - kl_loss: 2.3411

# %%
_, _, z = encoder.predict(x_test.reshape(x_test.shape[0], 1, -1, 4))
y_pred = decoder.predict(z)

# %%
x_test_reshape = x_test.reshape(x_test.shape[0], -1)

# %%
x_test_df = pd.DataFrame(x_test_reshape, columns = variables)

# %%
x_test_E = np.array(x_test_df[E])
x_test_pt = np.array(x_test_df[pt])
x_test_phi = np.array(x_test_df[phi])
x_test_eta = np.array(x_test_df[eta])

# %%
y_pred_reshape = y_pred.reshape(y_pred.shape[0], -1)

# %%
y_pred_df = pd.DataFrame(y_pred_reshape, columns = variables)

# %%
y_pred_E = np.array(y_pred_df[E])
y_pred_pt = np.array(y_pred_df[pt])
y_pred_phi = np.array(y_pred_df[phi])
y_pred_eta = np.array(y_pred_df[eta])

# %%
n, bins, patches = plt.hist(x_test_E.flatten(), 1000)

# %%
plt.figure(figsize=(10,7))
plt.xlim(0, 10)
plt.xlabel('Scaled Input', fontsize = 15)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel('Frequency', fontsize = 15)
plt.title('Channel 3 Energy Data Histogram', fontsize = 18)
plt.hist(x_test_E.flatten(), bins = bins, color='blue', log=True, label='Input Data', alpha=0.5)
plt.hist(y_pred_E.flatten(), bins = bins, color='orange', log=True, label='Prediction', alpha=0.5)
plt.legend()
plt.show()

# %%
n, bins, patches = plt.hist(x_test_pt.flatten(), 1000)

# %%
plt.figure(figsize=(10,7))
plt.xlim(0, 10)
plt.xlabel('Scaled Input', fontsize = 15)
plt.ylabel('Frequency', fontsize = 15)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.title('Channel 3 p$_T$ Data Histogram', fontsize = 18)
plt.hist(x_test_pt.flatten(), bins = bins, color='blue', log=True, label='Input Data', alpha=0.5)
plt.hist(y_pred_pt.flatten(), bins = bins, color='orange', log=True, label='Prediction', alpha=0.5)
plt.legend()
plt.show()

# %%
n, bins, patches = plt.hist(x_test_phi.flatten(), 1000)

# %%
plt.figure(figsize=(10,7))
plt.xlim(0, 10)
plt.xlabel('Scaled Input', fontsize = 15)
plt.ylabel('Frequency', fontsize = 15)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.title('Channel 3 Input $\phi$ Data Histogram', fontsize = 18)
plt.hist(x_test_phi.flatten(), bins = bins, color='blue', log=True, label='Input Data', alpha=0.5)
plt.hist(y_pred_phi.flatten(), bins = bins, color='orange', log=True, label='Prediction', alpha=0.5)
plt.legend()
plt.show()

# %%
n, bins, patches = plt.hist(x_test_eta.flatten(), 1000)

# %%
plt.figure(figsize=(10,7))
plt.xlim(0, 10)
plt.xlabel('Scaled Input', fontsize = 15)
plt.ylabel('Frequency', fontsize = 15)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.title('Channel 3 Input $\eta$ Data Histogram', fontsize = 18)
plt.hist(x_test_eta.flatten(), bins = bins, color='blue', log=True, label='Input Data', alpha=0.5)
plt.hist(y_pred_eta.flatten(), bins = bins, color='orange', log=True, label='Prediction', alpha=0.5)
plt.legend()
plt.show()

# %%
loss = [x for x in history_train.history['loss'] if x<100]
val_loss = [x for x in history_val.history['loss'] if x<100]
plt.figure(figsize = (10,7))
plt.plot(loss)
plt.plot(val_loss)
plt.title('Channel 3 Model Loss', fontsize = 18)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('Epoch', fontsize = 15)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(['Train', 'Test'])#, loc='upper left')
plt.show()

# %%
kl_loss = [x for x in history_train.history['kl_loss'] if x<10]
plt.figure(figsize = (10, 7))
plt.plot(kl_loss)
plt.title('Channel 3 Kullback-Liebler Loss', fontsize = 18)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('Epoch', fontsize = 15)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(['Train', 'Test'])#, loc = 'upper left')
plt.show()

# %%
recon_loss = [x for x in history_train.history['reconstruction_loss'] if x<100]
plt.figure(figsize = (10, 7))
plt.plot(recon_loss)
plt.title('Channel 3 Reconstruction (MSE) Loss', fontsize = 18)
plt.ylabel('Loss', fontsize = 15)
plt.xlabel('Epoch', fontsize = 15)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(['Train', 'Test'])#, loc = 'upper left')
plt.show()

# %% [markdown]
# fpr1, tpr1 = fpr_tpr_calc(path1, vae, x_test, df_bkg)
# fpr2, tpr2 = fpr_tpr_calc(path2, vae, x_test, df_bkg)
# fpr3, tpr3 = fpr_tpr_calc(path3, vae, x_test, df_bkg)
# fpr4, tpr4 = fpr_tpr_calc(path4, vae, x_test, df_bkg)
# fpr5, tpr5 = fpr_tpr_calc(path5, vae, x_test, df_bkg)
# fpr6, tpr6 = fpr_tpr_calc(path6, vae, x_test, df_bkg)
# fpr7, tpr7 = fpr_tpr_calc(path7, vae, x_test, df_bkg)

# %%
fprs = []
tprs = []
for path in paths:
    df = single_csv_to_df(path)
    if (len(df)-5)%2 != 0:
        num = str(int(((len(df.columns) - 5)/5) + 1))
        df['obj'+num]= -999
        df['E'+num] = -999
        df['pt'+num] = -999
        df['eta'+num] = -999
        df['phi'+num] = -999

    if (len(df.columns)< len(df_bkg.columns)):
        diff = int(((len(df_bkg.columns)-5)/5))-int(((len(df.columns)-5)/5))
        num = int(((len(df.columns) - 5)/5) + 1)
        for i in range(diff):
            df['obj'+str(num)]= -999
            df['E'+str(num)] = -999
            df['pt'+str(num)] = -999
            df['eta'+str(num)] = -999
            df['phi'+str(num)] = -999
            num+=1
    df = df.fillna(-999)
    variables = [entry for entry in df.columns if entry[0] == 'E'] + [entry for entry in df.columns if entry[0:2] == 'pt'] + [entry for entry in df.columns if entry[0:2] == 'et'] + [entry for entry in df.columns if entry[0:2] == 'ph']

    df = df[['process_ID']+variables]
    one_hot = pd.get_dummies(df['process_ID'])
    processes = one_hot.columns
    df.drop('process_ID', axis = 'columns', inplace = True)
    df = pd.concat([df, one_hot], sort = False, axis = 1)


    x = df[variables].values
    x_scaled = StandardScaler().fit_transform(x)
    df[variables] = x_scaled

    _, x_test_bsm, _, y_test_bsm = train_test_split(df[variables].values,
                                                    df[processes].values, 
                                                    shuffle = True,
                                                    random_state = 42,
                                                    test_size = 0.1)

    #x_train = x_train.reshape((x_train.shape[0], 1, -1, 4))
    x_test_bsm = x_test_bsm.reshape((x_test_bsm.shape[0], 1, -1, 4))
    _, _, z_bsm = encoder.predict(x_test_bsm.reshape(x_test_bsm.shape[0], 1, -1, 4))
    y_bsm = decoder.predict(z_bsm)
    _, _, z = encoder.predict(x_test.reshape(x_test.shape[0], 1, -1, 4))
    y_sm = decoder.predict(z)
    y_total = np.append(y_sm, y_bsm)
    y_sm = y_sm.flatten()
    y_bsm = y_bsm.flatten()
    
    
    y_true = np.append(np.zeros(len(y_sm)), np.ones(len(y_bsm)))
    y_total_norm = y_total/np.linalg.norm(y_total)
    
    fpr, tpr, _ = roc_curve(y_true, y_total_norm)
    fprs.append(fpr)
    tprs.append(tpr)

# %% [markdown]
# fpr1, tpr1 = fpr_tpr_calc(path1, vae, x_test, df_bkg)
# fpr2, tpr2 = fpr_tpr_calc(path2, vae, x_test, df_bkg)
# fpr3, tpr3 = fpr_tpr_calc(path3, vae, x_test, df_bkg)
# fpr4, tpr4 = fpr_tpr_calc(path4, vae, x_test, df_bkg)
# fpr5, tpr5 = fpr_tpr_calc(path5, vae, x_test, df_bkg)
# fpr6, tpr6 = fpr_tpr_calc(path6, vae, x_test, df_bkg)
# fpr7, tpr7 = fpr_tpr_calc(path7, vae, x_test, df_bkg)
# fpr8, tpr8 = fpr_tpr_calc(path8, vae, x_test, df_bkg)
# fpr9, tpr9 = fpr_tpr_calc(path9, vae, x_test, df_bkg)
# fpr10, tpr10 = fpr_tpr_calc(path10, vae, x_test, df_bkg)

# %%
colours = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'cyan', 'goldenrod', 'lavender']
#fprs = [fpr1, fpr2, fpr3, fpr4, fpr5, fpr6, fpr7, fpr8, fpr9, fpr10]
#tprs = [tpr1, tpr2, tpr3, tpr4, tpr5, tpr6, tpr7, tpr8, tpr9, tpr10]
signals = ['glgl1400_neutralino1100', 
           'glgl1600_neutralino800', 
           'gluino_1000.0_neutralino_1.0', 
           'monoV_Zp2000.0_DM_1.0', 
           'monojet_Zp2000.0_DM_50.0', 
           'monotop_200_A', 
           'sqsq1_sq1400_neut800', 
           'sqsq_sq1800_neut800', 
           'stlp_st1000', 
           'stop2b1000_neutralino300']

# %%
lw = 2
plt.figure(figsize = (10, 7))
plt.plot([0, 1], [0, 1], color = 'navy', lw = lw, linestyle = '--')
plt.xlim([0., 1.])
plt.ylim([0, 1.05])
plt.title('ROC for Channel 3', fontsize = 18)
for fpr, tpr, sig, col in zip(fprs, tprs, signals, colours):
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color = col, lw = lw, 
             label = '{} (area = {})'.format(sig, round(roc_auc, 2)))
plt.legend()
plt.xlabel('False Positive Rate', fontsize = 15)
plt.ylabel('True Positive Rate', fontsize = 15)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.show()

# %%
from performance import *

# %%
y_pred = y_pred.flatten()

# %%
AUC = []
epsilon1 = []
epsilon2 = []
epsilon3 = []

# %%
for i in paths:
    df_sig = single_csv_to_df(path1)
    if ((len(df_sig.columns)-5) % 2 != 0):
        num = str(int(((len(df_sig.columns) - 5)/5) + 1))
        df_sig['obj'+num]= -999
        df_sig['E'+num] = -999
        df_sig['pt'+num] = -999
        df_sig['eta'+num] = -999
        df_sig['phi'+num] = -999
        
    if (len(df_sig.columns)< len(df_bkg.columns)):
        diff = int(((len(df_bkg.columns)-5)/5))-int(((len(df_sig.columns)-5)/5))
        num = int(((len(df_sig.columns) - 5)/5) + 1)
        for i in range(diff):
            df_sig['obj'+str(num)]= -999
            df_sig['E'+str(num)] = -999
            df_sig['pt'+str(num)] = -999
            df_sig['eta'+str(num)] = -999
            df_sig['phi'+str(num)] = -999
            num+=1
    
    df = df_sig.fillna(-999)
    variables = [entry for entry in df.columns if entry[0] == 'E'] + [entry for entry in df.columns if entry[0:2] == 'pt'] + [entry for entry in df.columns if entry[0:2] == 'et'] + [entry for entry in df.columns if entry[0:2] == 'ph']

    #Now we one_hot encode the data to make sure we have a class definition
    df = df[['process_ID']+variables]
    one_hot = pd.get_dummies(df['process_ID'])
    processes = one_hot.columns
    df.drop('process_ID', axis = 'columns', inplace = True)
    df = pd.concat([df, one_hot], sort = False, axis = 1)

    x = df[variables].values
    x_scaled = StandardScaler().fit_transform(x)
    df[variables] = x_scaled

    x_train, x_test, y_train, y_test = train_test_split(df[variables].values,
                                                        df[processes].values, 
                                                        shuffle = True,
                                                        random_state = 42,
                                                        test_size = 0.1)
    x_test = x_test.reshape((x_test.shape[0], 1, -1, 4))

    y_pred_sig = vae.predict(x_test)
    y_pred_sig = y_pred_sig.flatten()

    auc, ep1, ep2, ep3 = performance(y_pred, y_pred_sig)

    AUC.append(auc)
    epsilon1.append(ep1)
    epsilon2.append(ep2)
    epsilon3.append(ep3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-92aef7702588> in <module>
#      41     x_test = x_test.reshape((x_test.shape[0], 1, -1, 4))
#      42
# ---> 43     y_pred_sig = vae.predict(x_test)
#      44     y_pred_sig = y_pred_sig.flatten()
#      45
#
# NameError: name 'vae' is not defined

# %%
AUC

# %%
epsilon1

# %%
epsilon2

# %%
epsilon3
